# %% [markdown]
# # Data Understanding - 8. Autocorrelation
#
# Week 2

# %%
#add 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.graphics.tsaplots import plot_acf


os.chdir('C:\\Users\\Sükrü\\sciebo\\TU Dortmund\\2022_06_WiSe\\Case Study') 

df = pd.read_excel('OH14_01_26-07_19.xls')

df = df.iloc[5:]

plt.rc("figure", figsize=(16,4))
plot_acf(df[['Wärme.1']], lags = 300)
plot_acf(df[['Wärme.1']], lags = 98)
plot_acf(df[['Wärme.8']], lags = 98)

plot_acf(df[['Wärme.4']], lags = 300)
plot_acf(df[['Wärme.11']], lags = 300)

# %%
from statsmodels.graphics.tsaplots import plot_acf
df1 = pd.read_excel('OH12_01_26-07_19.xls')

df1 = df1.iloc[5:]

plot_acf(df1[['Wärme.3']], lags = 300)
